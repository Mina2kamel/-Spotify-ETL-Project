# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from spotipy) (5.0.3)
# Requirement already satisfied: requests>=2.25.0 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from spotipy) (1.26.13)
# Requirement already satisfied: async-timeout>=4.0.3 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (2022.12.7)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1&dlsi=3998e1ebc6224c5e"

# %%
playlist_URI = playlist_link.split('/')[-1].split('?')[0]
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'single',
#  'href': 'https://api.spotify.com/v1/albums/5quMTd5zeI9yW5UDua8wS4',
#  'id': '5quMTd5zeI9yW5UDua8wS4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273659cd4673230913b3918e0d5',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02659cd4673230913b3918e0d5',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851659cd4673230913b3918e0d5',
#    'width': 64}],
#  'name': 'Espresso',
#  'release_date': '2024-04-12',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:5quMTd5zeI9yW5UDua8wS4',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#    'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#    'id': '74KM79TiuVKeVCqs8QtB0B',
#    'name': 'Sabrina Carpenter',
#    'type': 'artist',
#    'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  'total_tracks': 1}

# %%
album_id = data['items'][0]['track']['album']['id']
album_id
# Out:
# '5quMTd5zeI9yW5UDua8wS4'

# %%
album_name = data['items'][0]['track']['album']['name']
album_name
# Out:
# 'Espresso'

# %%
album_release_date = data['items'][0]['track']['album']['release_date']
album_release_date
# Out:
# '2024-04-12'

# %%
album_total_tracks = data['items'][0]['track']['album']['total_tracks']
album_total_tracks
# Out:
# 1

# %%
album_url = data['items'][0]['track']['album']['external_urls']['spotify']
album_url
# Out:
# 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']

    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '5bBaoign62r1i7OV8w7mi9',
#   'name': 'Please Please Please',
#   'release_date': '2024-06-06',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '6Xuu2z00jxRPZei4IJ9neK',
#   'name': 'Houdini',
#   'release_date': '2024-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Xuu2z00jxRPZei4IJ9neK'},
#  {'album_id': '2Z1gnUf3nbn6DtwZSUIH54',
#   'name': 'MILLION DOLLAR BABY',
#   'release_date': '2024-04-26',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/2Z1gnUf3nbn6DtwZSUIH54'},
#  {'album_id': '5tSQtQGkrCJx3hoQxmLgfM',
#   'name': 'Gata Only',
#   'release_date': '2024-02-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5tSQtQGkrCJx3hoQxmLgfM'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '3P4SQqMMgjqfqVxgLwtYRk',
#   'name': 'Unreal Unearth: Unheard',
#   'release_date': '2024-03-22',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/3P4SQqMMgjqfqVxgLwtYRk'},
#  {'album_id': '1woYXxyyxTQJ0E0AhZE6mj',
#   'name': 'I Had Some Help',
#   'release_date': '2024-05-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1woYXxyyxTQJ0E0AhZE6mj'},
#  {'album_id': '0DLvFVIfwt3OHdK9kGeEM3',
#   'name': "Where I've Been, Isn't Where I'm Going",
#   'release_date': '2024-05-31',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0DLvFVIfwt3OHdK9kGeEM3'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'name': 'Fireworks & Rollerblades',
#   'release_date': '2024-04-05',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/168CdR21lfn0TTyw1Pkdcm'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'name': 'Not Like Us',
#   'release_date': '2024-05-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '5HIWDdg3g9CTOtnevKDl1z',
#   'name': 'i like the way you kiss me',
#   'release_date': '2024-03-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5HIWDdg3g9CTOtnevKDl1z'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '4AzPr5SUpNF553eC1d3aRy',
#   'name': 'BAND4BAND (feat. Lil Baby)',
#   'release_date': '2024-05-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4AzPr5SUpNF553eC1d3aRy'},
#  {'album_id': '4JDXBZdRPId4devseaAOKH',
#   'name': 'DECIDE',
#   'release_date': '2022-09-16',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'},
#  {'album_id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'name': 'THE TORTURED POETS DEPARTMENT',
#   'release_date': '2024-04-18',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'},
#  {'album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'name': 'Stargazing',
#   'release_date': '2024-05-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3VNxRarx9HUI5w7DHv0TBj'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'name': "I've Tried Everything But Therapy (Part 1)",
#   'release_date': '2023-09-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#  {'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'name': 'eternal sunshine',
#   'release_date': '2024-03-08',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5EYKrEDnKhhcNxGedaRQeK'},
#  {'album_id': '6zXydimgenc15N3LWmf0cn',
#   'name': 'Never Let Go',
#   'release_date': '2024-06-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6zXydimgenc15N3LWmf0cn'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'name': 'Good Luck, Babe!',
#   'release_date': '2024-04-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '3uzutRS5qX4ng5Skjh5S6W',
#   'name': 'Santa',
#   'release_date': '2024-04-03',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/3uzutRS5qX4ng5Skjh5S6W'},
#  {'album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'name': 'The Idol Episode 4 (Music from the HBO Original Series)',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7tzVd1fwkxsorytCBjEJkU'},
#  {'album_id': '3EWJoKrG9XnCjvAPzkQZ88',
#   'name': 'EL ÚLTIMO BAILE',
#   'release_date': '2024-05-23',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3EWJoKrG9XnCjvAPzkQZ88'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '7LRZfujsTLyy814AnMSdtT',
#   'name': 'Pink Skies',
#   'release_date': '2024-05-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7LRZfujsTLyy814AnMSdtT'},
#  {'album_id': '40HsqPqeSR9Xe3IyAJWr6e',
#   'name': 'What Happens Now?',
#   'release_date': '2024-02-16',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/40HsqPqeSR9Xe3IyAJWr6e'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '0lgs2Sa82lyX89nBUWyUy6',
#   'name': 'FERXXOCALIPSIS',
#   'release_date': '2023-12-01',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0lgs2Sa82lyX89nBUWyUy6'},
#  {'album_id': '3PlCMwyq6nuQYtoYproV1o',
#   'name': 'Belong Together',
#   'release_date': '2024-02-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3PlCMwyq6nuQYtoYproV1o'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'name': 'Fireworks & Rollerblades',
#   'release_date': '2024-04-05',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/168CdR21lfn0TTyw1Pkdcm'},
#  {'album_id': '6WkOBnYkj6y5iSr14uhUZF',
#   'name': 'Si No Quieres No',
#   'release_date': '2024-03-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6WkOBnYkj6y5iSr14uhUZF'},
#  {'album_id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'name': 'THE TORTURED POETS DEPARTMENT',
#   'release_date': '2024-04-18',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'},
#  {'album_id': '4ecjQGViGCD4snnZ3QJOEL',
#   'name': 'SI NO ES CONTIGO',
#   'release_date': '2024-05-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4ecjQGViGCD4snnZ3QJOEL'},
#  {'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'name': 'I Love You.',
#   'release_date': '2013-04-19',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '4iqbFIdGOTzXeDtt9owjQn',
#   'name': "WE DON'T TRUST YOU",
#   'release_date': '2024-03-22',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4iqbFIdGOTzXeDtt9owjQn'},
#  {'album_id': '5pSk3c3wVwnb2arb6ohCPU',
#   'name': 'GOLDEN',
#   'release_date': '2023-11-03',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5pSk3c3wVwnb2arb6ohCPU'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '1fmBMCSSkSlvxyoy1vut2k',
#   'name': 'Saturn',
#   'release_date': '2024-02-22',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1fmBMCSSkSlvxyoy1vut2k'},
#  {'album_id': '50ZenUP4O2Q5eCy2NRNvuz',
#   'name': 'Stick Season',
#   'release_date': '2022-10-14',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/50ZenUP4O2Q5eCy2NRNvuz'},
#  {'album_id': '4sD1qg4jwTZR4mvR4Iflk5',
#   'name': 'Strange Trails',
#   'release_date': '2015-04-06',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4sD1qg4jwTZR4mvR4Iflk5'},
#  {'album_id': '0d91zWX7A6i4iPLgJc9oy6',
#   'name': 'Volver Al Futuro',
#   'release_date': '2024-05-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0d91zWX7A6i4iPLgJc9oy6'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'name': 'greedy',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '6rIbiUMmZJfqJRnXhVxFvg',
#   'name': 'Dream Your Life Away',
#   'release_date': '2014-09-08',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/6rIbiUMmZJfqJRnXhVxFvg'},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'name': 'UTOPIA',
#   'release_date': '2023-07-28',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'},
#  {'album_id': '6irebIc6UO8fN0jl4UlzBS',
#   'name': 'SUPER REAL ME',
#   'release_date': '2024-03-25',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6irebIc6UO8fN0jl4UlzBS'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df
# Out:
#                   album_id                                               name  \
# 0   5quMTd5zeI9yW5UDua8wS4                                           Espresso
# 1   5bBaoign62r1i7OV8w7mi9                               Please Please Please
# 2   7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 3   6Xuu2z00jxRPZei4IJ9neK                                            Houdini
# 4   2Z1gnUf3nbn6DtwZSUIH54                                MILLION DOLLAR BABY
# 5   5tSQtQGkrCJx3hoQxmLgfM                                          Gata Only
# 7   3P4SQqMMgjqfqVxgLwtYRk                            Unreal Unearth: Unheard
# 8   1woYXxyyxTQJ0E0AhZE6mj                                    I Had Some Help
# 9   0DLvFVIfwt3OHdK9kGeEM3             Where I've Been, Isn't Where I'm Going
# 10  168CdR21lfn0TTyw1Pkdcm                           Fireworks & Rollerblades
# 11  5JjnoGJyOxfSZUZtk2rRwZ                                        Not Like Us
# 12  5HIWDdg3g9CTOtnevKDl1z                         i like the way you kiss me
# 14  4AzPr5SUpNF553eC1d3aRy                         BAND4BAND (feat. Lil Baby)
# 15  4JDXBZdRPId4devseaAOKH                                             DECIDE
# 16  1Mo4aZ8pdj6L1jx8zSwJnt                      THE TORTURED POETS DEPARTMENT
# 17  3VNxRarx9HUI5w7DHv0TBj                                         Stargazing
# 18  7nacKlk586eLRBSIsrk9DB         I've Tried Everything But Therapy (Part 1)
# 19  5EYKrEDnKhhcNxGedaRQeK                                   eternal sunshine
# 20  6zXydimgenc15N3LWmf0cn                                       Never Let Go
# 21  1WAjjRMfZjEXtB0lQrAw6Q                                   Good Luck, Babe!
# 22  3uzutRS5qX4ng5Skjh5S6W                                              Santa
# 23  7tzVd1fwkxsorytCBjEJkU  The Idol Episode 4 (Music from the HBO Origina...
# 24  3EWJoKrG9XnCjvAPzkQZ88                                    EL ÚLTIMO BAILE
# 25  1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 26  7LRZfujsTLyy814AnMSdtT                                         Pink Skies
# 27  40HsqPqeSR9Xe3IyAJWr6e                                  What Happens Now?
# 29  5r36AJ6VOJtp00oxSkBZ5h                                      Harry's House
# 30  0lgs2Sa82lyX89nBUWyUy6                                     FERXXOCALIPSIS
# 31  3PlCMwyq6nuQYtoYproV1o                                    Belong Together
# 33  6WkOBnYkj6y5iSr14uhUZF                                   Si No Quieres No
# 35  4ecjQGViGCD4snnZ3QJOEL                                   SI NO ES CONTIGO
# 36  4xkM0BwLM9H2IUcbYzpcBI                                        I Love You.
# 39  4iqbFIdGOTzXeDtt9owjQn                                 WE DON'T TRUST YOU
# 40  5pSk3c3wVwnb2arb6ohCPU                                             GOLDEN
# 41  78bpIziExqiI9qztvNFlQu                                                 AM
# 42  1fmBMCSSkSlvxyoy1vut2k                                             Saturn
# 43  50ZenUP4O2Q5eCy2NRNvuz                                       Stick Season
# 44  4sD1qg4jwTZR4mvR4Iflk5                                     Strange Trails
# 45  0d91zWX7A6i4iPLgJc9oy6                                   Volver Al Futuro
# 46  3UOV8XvCwMKaATRNXrYCjN                                             greedy
# 47  6rIbiUMmZJfqJRnXhVxFvg                               Dream Your Life Away
# 48  18NOKLkZETa4sWwLMIm0UZ                                             UTOPIA
# 49  6irebIc6UO8fN0jl4UlzBS                                      SUPER REAL ME
#
#    release_date  total_tracks  \
# 0    2024-04-12             1
# 1    2024-06-06             2
# 2    2024-05-17            10
# 3    2024-05-31             1
# 4    2024-04-26             2
# 5    2024-02-02             1
# 7    2024-03-22            20
# 8    2024-05-10             1
# 9    2024-05-31            12
# 10   2024-04-05            15
# 11   2024-05-04             1
# 12   2024-03-19             1
# 14   2024-05-23             1
# 15   2022-09-16            13
# 16   2024-04-18            16
# 17   2024-05-10             1
# 18   2023-09-15            10
# 19   2024-03-08            13
# 20   2024-06-07             1
# 21   2024-04-05             1
# 22   2024-04-03             2
# 23   2023-06-23             3
# 24   2024-05-23            13
# 25   2019-08-23            18
# 26   2024-05-24             1
# 27   2024-02-16             8
# 29   2022-05-20            13
# 30   2023-12-01            10
# 31   2024-02-16             1
# 33   2024-03-10             1
# 35   2024-05-23             1
# 36   2013-04-19            11
# 39   2024-03-22            17
# 40   2023-11-03            11
# 41   2013-09-09            12
# 42   2024-02-22             5
# 43   2022-10-14            14
# 44   2015-04-06            14
# 45   2024-05-30             1
# 46   2023-09-15             1
# 47   2014-09-08            13
# 48   2023-07-28            19
# 49   2024-03-25             4
#
#                                                   url
# 0   https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 1   https://open.spotify.com/album/5bBaoign62r1i7O...
# 2   https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 3   https://open.spotify.com/album/6Xuu2z00jxRPZei...
# 4   https://open.spotify.com/album/2Z1gnUf3nbn6Dtw...
# 5   https://open.spotify.com/album/5tSQtQGkrCJx3ho...
# 7   https://open.spotify.com/album/3P4SQqMMgjqfqVx...
# 8   https://open.spotify.com/album/1woYXxyyxTQJ0E0...
# 9   https://open.spotify.com/album/0DLvFVIfwt3OHdK...
# 10  https://open.spotify.com/album/168CdR21lfn0TTy...
# 11  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 12  https://open.spotify.com/album/5HIWDdg3g9CTOtn...
# 14  https://open.spotify.com/album/4AzPr5SUpNF553e...
# 15  https://open.spotify.com/album/4JDXBZdRPId4dev...
# 16  https://open.spotify.com/album/1Mo4aZ8pdj6L1jx...
# 17  https://open.spotify.com/album/3VNxRarx9HUI5w7...
# 18  https://open.spotify.com/album/7nacKlk586eLRBS...
# 19  https://open.spotify.com/album/5EYKrEDnKhhcNxG...
# 20  https://open.spotify.com/album/6zXydimgenc15N3...
# 21  https://open.spotify.com/album/1WAjjRMfZjEXtB0...
# 22  https://open.spotify.com/album/3uzutRS5qX4ng5S...
# 23  https://open.spotify.com/album/7tzVd1fwkxsoryt...
# 24  https://open.spotify.com/album/3EWJoKrG9XnCjvA...
# 25  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 26  https://open.spotify.com/album/7LRZfujsTLyy814...
# 27  https://open.spotify.com/album/40HsqPqeSR9Xe3I...
# 29  https://open.spotify.com/album/5r36AJ6VOJtp00o...
# 30  https://open.spotify.com/album/0lgs2Sa82lyX89n...
# 31  https://open.spotify.com/album/3PlCMwyq6nuQYto...
# 33  https://open.spotify.com/album/6WkOBnYkj6y5iSr...
# 35  https://open.spotify.com/album/4ecjQGViGCD4snn...
# 36  https://open.spotify.com/album/4xkM0BwLM9H2IUc...
# 39  https://open.spotify.com/album/4iqbFIdGOTzXeDt...
# 40  https://open.spotify.com/album/5pSk3c3wVwnb2ar...
# 41  https://open.spotify.com/album/78bpIziExqiI9qz...
# 42  https://open.spotify.com/album/1fmBMCSSkSlvxyo...
# 43  https://open.spotify.com/album/50ZenUP4O2Q5eCy...
# 44  https://open.spotify.com/album/4sD1qg4jwTZR4mv...
# 45  https://open.spotify.com/album/0d91zWX7A6i4iPL...
# 46  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 47  https://open.spotify.com/album/6rIbiUMmZJfqJRn...
# 48  https://open.spotify.com/album/18NOKLkZETa4sWw...
# 49  https://open.spotify.com/album/6irebIc6UO8fN0j...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#   'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#   'id': '74KM79TiuVKeVCqs8QtB0B',
#   'name': 'Sabrina Carpenter',
#   'type': 'artist',
#   'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}]

# %%
artist_list = []
for row in data['items']:
    for item in row['track']['artists']:
        artist_id = item['id']
        artist_name = item['name']
        external_url = item['external_urls']['spotify']
        artist_dict = {'artist_id':artist_id, 'artist_name':artist_name, 'external_url': external_url}
        artist_list.append(artist_dict)

# %%
artists_df = pd.DataFrame.from_dict(artist_list)
artists_df = artists_df.drop_duplicates(subset=['artist_id'])
artists_df
# Out:
#                  artist_id        artist_name  \
# 0   74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 2   6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 3   7dGJo4pcD2V6oG8kP0tJRR             Eminem
# 4   1WaFQSHVGZQJTbf0BdxdNo      Tommy Richman
# 5   7CvTknweLr9feJtRGrpDBy         FloyyMenor
# 6   1Yj5Xey7kTwvZla8sqdsdE            Cris Mj
# 8   2FXC3k01G6Gw61bmprjgqS             Hozier
# 9   246dkjvS1zLTtiykXe5h60        Post Malone
# 10  4oUHIQIBe0LHzYfvXNW4QM      Morgan Wallen
# 11  3y2cIKLjiOlp1Np37WiUdH          Shaboozey
# 12  22wbnEMDvgVIAGdFeek6ET       Benson Boone
# 13  2YZyLoL8N0Wb9xBt1NhZWg     Kendrick Lamar
# 14  0PCCGZ0wGLizHt2KZ7hhA2            Artemas
# 16  5H4yInM5zmHqpKIoMNAx4r        Central Cee
# 17  5f7VJjfbwm532GiveGC0ZK           Lil Baby
# 18  5p9HO3XC5P3BLxJs5Mtrhm                Djo
# 19  06HL4z0CvFAxyc27GXpf02       Taylor Swift
# 21  3bO19AOone0ubCsfDXDtYt        Myles Smith
# 22  33qOK5uJ8AR2xuQQAhHump        Teddy Swims
# 23  66CXWjxzNUsdJxJ2JdwvnR      Ariana Grande
# 24  6HaGTQPmzraVmaVxvz6EUc          Jung Kook
# 25  7GlBOeep6PqTfFi59PTUUN      Chappell Roan
# 26  1fctva4kpRbg2k3v7kwRuS            Rvssian
# 27  1mcTU81TzQhprhouKaTkpq     Rauw Alejandro
# 28  3ZpEKRjHaHANcpk10u6Ntq         Ayra Starr
# 29  1Xyo4u8uXC1ZmMpatF05PJ         The Weeknd
# 30  250b0Wlc5Vk0CoUsaCY84M             JENNIE
# 31  1pBLC0qVRTB5zVMuteQ9jJ     Lily-Rose Depp
# 32  2x7PC78TmgqpEIjaGAZ0Oz             Trueno
# 34  40ZNYROS4zLfyyBSs2PGe2         Zach Bryan
# 35  7Ez6lTtSMjMf2YSYpukP1I              Dasha
# 37  6KImCVD70vtIoJWnq6nGn3       Harry Styles
# 38  2LRoIwlKmHjgvigdNGBHNo               Feid
# 39  7jAs1uPnpfNmT6e5qtEPxq          ATL Jacob
# 40  11p2E654TTU8e0nZWBR4AL         Mark Ambor
# 42  0pePYDrJGk8gqMRbXrLJC8   Luis R Conriquez
# 43  6pV5zH2LzjOUHaAvENdMMa         Neton Vega
# 46  77SW9BnxLY8rJ0RciFqkHh  The Neighbourhood
# 49  1RyvyyTE3xzB2ZywiAwp0i             Future
# 50  0iEtIxbK0KxaSlF7G42ZOp       Metro Boomin
# 53  3MdXrJWsbVzdn6fe5JYkSQ              Latto
# 54  7Ln80lUS6He07XvHI8qqHH     Arctic Monkeys
# 55  7tYKF4w9nC0nq9CsPZTHyP                SZA
# 56  2RQXRUsr4IW1f3mKyKsy4B         Noah Kahan
# 57  6ltzsmQQbmdoHHbLZ4ZN25         Lord Huron
# 58  3l9G1G9MxH6DaRhwLklaf5       Oscar Maydon
# 59  7Gi6gjaWy3DxyilpF1a8Is           Junior H
# 60  45dkTj5sMRSjrmBSBeiHym         Tate McRae
# 61  10exVja0key0uqUkk6LJRT          Vance Joy
# 62  0Y5tJX1MQlPlqiwlOH1tJY       Travis Scott
# 63  699OTQXzgjhIYAHMy9RyPD      Playboi Carti
# 64  36cgvBn0aadzOijnjjwqMN              ILLIT
#
#                                          external_url
# 0   https://open.spotify.com/artist/74KM79TiuVKeVC...
# 2   https://open.spotify.com/artist/6qqNVTkY8uBg9c...
# 3   https://open.spotify.com/artist/7dGJo4pcD2V6oG...
# 4   https://open.spotify.com/artist/1WaFQSHVGZQJTb...
# 5   https://open.spotify.com/artist/7CvTknweLr9feJ...
# 6   https://open.spotify.com/artist/1Yj5Xey7kTwvZl...
# 8   https://open.spotify.com/artist/2FXC3k01G6Gw61...
# 9   https://open.spotify.com/artist/246dkjvS1zLTti...
# 10  https://open.spotify.com/artist/4oUHIQIBe0LHzY...
# 11  https://open.spotify.com/artist/3y2cIKLjiOlp1N...
# 12  https://open.spotify.com/artist/22wbnEMDvgVIAG...
# 13  https://open.spotify.com/artist/2YZyLoL8N0Wb9x...
# 14  https://open.spotify.com/artist/0PCCGZ0wGLizHt...
# 16  https://open.spotify.com/artist/5H4yInM5zmHqpK...
# 17  https://open.spotify.com/artist/5f7VJjfbwm532G...
# 18  https://open.spotify.com/artist/5p9HO3XC5P3BLx...
# 19  https://open.spotify.com/artist/06HL4z0CvFAxyc...
# 21  https://open.spotify.com/artist/3bO19AOone0ubC...
# 22  https://open.spotify.com/artist/33qOK5uJ8AR2xu...
# 23  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 24  https://open.spotify.com/artist/6HaGTQPmzraVma...
# 25  https://open.spotify.com/artist/7GlBOeep6PqTfF...
# 26  https://open.spotify.com/artist/1fctva4kpRbg2k...
# 27  https://open.spotify.com/artist/1mcTU81TzQhprh...
# 28  https://open.spotify.com/artist/3ZpEKRjHaHANcp...
# 29  https://open.spotify.com/artist/1Xyo4u8uXC1ZmM...
# 30  https://open.spotify.com/artist/250b0Wlc5Vk0Co...
# 31  https://open.spotify.com/artist/1pBLC0qVRTB5zV...
# 32  https://open.spotify.com/artist/2x7PC78TmgqpEI...
# 34  https://open.spotify.com/artist/40ZNYROS4zLfyy...
# 35  https://open.spotify.com/artist/7Ez6lTtSMjMf2Y...
# 37  https://open.spotify.com/artist/6KImCVD70vtIoJ...
# 38  https://open.spotify.com/artist/2LRoIwlKmHjgvi...
# 39  https://open.spotify.com/artist/7jAs1uPnpfNmT6...
# 40  https://open.spotify.com/artist/11p2E654TTU8e0...
# 42  https://open.spotify.com/artist/0pePYDrJGk8gqM...
# 43  https://open.spotify.com/artist/6pV5zH2LzjOUHa...
# 46  https://open.spotify.com/artist/77SW9BnxLY8rJ0...
# 49  https://open.spotify.com/artist/1RyvyyTE3xzB2Z...
# 50  https://open.spotify.com/artist/0iEtIxbK0KxaSl...
# 53  https://open.spotify.com/artist/3MdXrJWsbVzdn6...
# 54  https://open.spotify.com/artist/7Ln80lUS6He07X...
# 55  https://open.spotify.com/artist/7tYKF4w9nC0nq9...
# 56  https://open.spotify.com/artist/2RQXRUsr4IW1f3...
# 57  https://open.spotify.com/artist/6ltzsmQQbmdoHH...
# 58  https://open.spotify.com/artist/3l9G1G9MxH6DaR...
# 59  https://open.spotify.com/artist/7Gi6gjaWy3Dxyi...
# 60  https://open.spotify.com/artist/45dkTj5sMRSjrm...
# 61  https://open.spotify.com/artist/10exVja0key0uq...
# 62  https://open.spotify.com/artist/0Y5tJX1MQlPlqi...
# 63  https://open.spotify.com/artist/699OTQXzgjhIYA...
# 64  https://open.spotify.com/artist/36cgvBn0aadzOi...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
songs_df = pd.DataFrame.from_dict(song_list)
songs_df = songs_df.drop_duplicates(subset=['song_id'])
songs_df
# Out:
#                    song_id                                       song_name  \
# 0   2qSkIjg1o9h3YT9RAgYN75                                        Espresso
# 1   5N3hjp1WNayUPZrA8kJmJP                            Please Please Please
# 2   6dOtVTDdiauQNBQEDOtlAB                              BIRDS OF A FEATHER
# 3   2HYFX63wP3otVIvopRS99Z                                         Houdini
# 4   5AJ9hqTS2wcFQCELCFRO7A                             MILLION DOLLAR BABY
# 5   6XjDF6nds4DE2BBbagZol6                                       Gata Only
# 6   629DixmZGHc7ILtEntuiWE                                           LUNCH
# 7   5Z0UnEtpLDQyYlWwgi8m9C                                       Too Sweet
# 8   7221xIgOnuakPdLqT0F3nP           I Had Some Help (Feat. Morgan Wallen)
# 9   5fZJQrFKWQLb7FpJXZ1g7K                              A Bar Song (Tipsy)
# 10  3xkHsmpQCBMytMJNiDf3Ii                                Beautiful Things
# 11  6AI3ezQ4o3HUoP6Dhudph3                                     Not Like Us
# 12  2GxrNKugF82CnoRFbQfzPf                      i like the way you kiss me
# 13  7BRD7x5pt8Lqa1eGYC4dzj                                         CHIHIRO
# 14  7iabz12vAuVQYyekFIWJxD                      BAND4BAND (feat. Lil Baby)
# 15  3qhlB30KknSejmIvZZLjOD                                End of Beginning
# 16  2OzhQlSqBEmt7hmkYxfT6m                   Fortnight (feat. Post Malone)
# 17  3Vr3zh0r7ALn8VLqCiRR10                                      Stargazing
# 18  17phhZDn6oGtzMe56NuWvj                                    Lose Control
# 19  51ZQ1vr10ffzbwIjDCwqm4        we can't be friends (wait for your love)
# 20  2nRMW95dnOILirpjbksLTs                                    Never Let Go
# 21  0WbMK4wrZ1wFSty9F7FCgu                                Good Luck, Babe!
# 22  6a9Z1jUms915w4O7N1PxjY                                           Santa
# 23  7CyPwkp0oE8Ro9Dd5CUDjW  One Of The Girls (with JENNIE, Lily Rose Depp)
# 24  1pymWRCuZfCd0zdiBJo0Hj                               REAL GANGSTA LOVE
# 25  1BxfuPKGuaTgP7aM0Bbdwr                                    Cruel Summer
# 26  4ZJ4vzLQekI0WntDbanNC7                                      Pink Skies
# 27  2uqYupMHANxnwgeiXTZXzd                     Austin (Boots Stop Workin')
# 28  3QaPy1KgI7nu9FJEQUgn6h                                      WILDFLOWER
# 29  4Dvkj6JhhA12EX05fT7y2e                                       As It Was
# 30  7bywjHOc0wSjGGbj04XbVi                                            LUNA
# 31  5uQ7de4EWjb3rkcFxyEOpu                                 Belong Together
# 32  51eSHglvG1RJXtL3qI5trr                                    Slow It Down
# 33  1C84d9abZVKWHT2YYpoean                                Si No Quieres No
# 34  4q5YezDOIPcoLr8R81x9qy                 I Can Do It With a Broken Heart
# 35  5Uptvz6j1sjDKxidAcnH2L                                SI NO ES CONTIGO
# 36  2QjOHCTQ1Jl3zawyYOpxh6                                 Sweater Weather
# 8   246dkjvS1zLTtiykXe5h60
# 9   3y2cIKLjiOlp1Np37WiUdH
# 10  22wbnEMDvgVIAGdFeek6ET
# 11  2YZyLoL8N0Wb9xBt1NhZWg
# 12  0PCCGZ0wGLizHt2KZ7hhA2
# 13  6qqNVTkY8uBg9cP3Jd7DAH
# 14  5H4yInM5zmHqpKIoMNAx4r
# 15  5p9HO3XC5P3BLxJs5Mtrhm
# 16  06HL4z0CvFAxyc27GXpf02
# 17  3bO19AOone0ubCsfDXDtYt
# 18  33qOK5uJ8AR2xuQQAhHump
# 19  66CXWjxzNUsdJxJ2JdwvnR
# 20  6HaGTQPmzraVmaVxvz6EUc
# 21  7GlBOeep6PqTfFi59PTUUN
# 22  1fctva4kpRbg2k3v7kwRuS
# 23  1Xyo4u8uXC1ZmMpatF05PJ
# 24  2x7PC78TmgqpEIjaGAZ0Oz
# 25  06HL4z0CvFAxyc27GXpf02
# 26  40ZNYROS4zLfyyBSs2PGe2
# 27  7Ez6lTtSMjMf2YSYpukP1I
# 28  6qqNVTkY8uBg9cP3Jd7DAH
# 29  6KImCVD70vtIoJWnq6nGn3
# 30  2LRoIwlKmHjgvigdNGBHNo
# 31  11p2E654TTU8e0nZWBR4AL
# 32  22wbnEMDvgVIAGdFeek6ET
# 33  0pePYDrJGk8gqMRbXrLJC8
# 34  06HL4z0CvFAxyc27GXpf02
# 35  1Yj5Xey7kTwvZla8sqdsdE
# 36  77SW9BnxLY8rJ0RciFqkHh
# 37  6qqNVTkY8uBg9cP3Jd7DAH
# 38  6qqNVTkY8uBg9cP3Jd7DAH
# 39  1RyvyyTE3xzB2ZywiAwp0i
# 40  6HaGTQPmzraVmaVxvz6EUc
# 41  7Ln80lUS6He07XvHI8qqHH
# 42  7tYKF4w9nC0nq9CsPZTHyP
# 43  2RQXRUsr4IW1f3mKyKsy4B
# 44  6ltzsmQQbmdoHHbLZ4ZN25
# 45  3l9G1G9MxH6DaRhwLklaf5
# 46  45dkTj5sMRSjrmBSBeiHym
# 47  10exVja0key0uqUkk6LJRT
# 48  0Y5tJX1MQlPlqiwlOH1tJY
# 49  36cgvBn0aadzOijnjjwqMN

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     object
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.5+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      43 non-null     object
#  1   name          43 non-null     object
#  2   release_date  43 non-null     object
#  3   total_tracks  43 non-null     int64
#  4   url           43 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.0+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
songs_df['song_added'] = pd.to_datetime(songs_df['song_added'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      43 non-null     object
#  1   name          43 non-null     object
#  2   release_date  43 non-null     datetime64[ns]
#  3   total_tracks  43 non-null     int64
#  4   url           43 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.0+ KB
